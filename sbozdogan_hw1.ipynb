# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
#load the datasets
r15 = pd.read_csv("R15.txt", sep="\t", header=None)
jain = pd.read_csv("jain.txt", sep="\t", header=None)

# %%
r15.head()
# Out:
#         0       1  2
# 0   9.802  10.132  1
# 1  10.350   9.768  1
# 2  10.098   9.988  1
# 3   9.730   9.910  1
# 4   9.754  10.430  1

# %%
jain.head()
# Out:
#       0      1  2
# 0  0.85  17.45  2
# 1  0.75  15.60  2
# 2  3.30  15.45  2
# 3  5.25  14.20  2
# 4  4.90  15.65  2

# %%
r15.columns = ['x', 'y', 'class']

# %%
xpoints = r15['x']
ypoints = r15['y']

# %%
plt.scatter(xpoints, ypoints, edgecolors='r')
plt.title('R15 Scatter Plot')
plt.show()

# %%
jain.columns = ['a', 'b', 'class']

# %%
apoints = jain['a']
bpoints = jain['b']

# %%
plt.scatter(apoints, bpoints, edgecolor='r')
plt.title('Jain Scatter Plot')
plt.show()

# %%
from sklearn import preprocessing
from sklearn.cluster import KMeans 
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
mms = MinMaxScaler() #give equal importance to all features
mms.fit(jain)
data_transformed = mms.transform(jain)

# %%
Sum_of_squared_distances = []
K= range(1,11)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(data_transformed)
    Sum_of_squared_distances.append(km.inertia_)

# %%
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
def kmeans(X, n_clusters):
    ss = StandardScaler()
    X = ss.fit_transform(X)
    kms = KMeans(n_clusters=n_clusters)
    kms.fit(X)
    y_pred = kms.predict(X)
    plt.scatter(X[:,0], X[:,1],c=y_pred, cmap='Paired')
    plt.title("K-means")

# %%
kmeans(r15, n_clusters=15) #Optimal cluster number is 15

# %%
kmeans(jain, n_clusters=2) #Optimal cluster number is 2

# %%
kmeans(r15, n_clusters=6)  #See the effect of changing k

# %%
kmeans(jain, n_clusters=5) #See the effect of changing k
